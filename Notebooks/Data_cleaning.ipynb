# %%
import pandas as pd

# %%
# !kaggle datasets download -d shivamb/bank-customer-segmentation
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shivamb/bank-customer-segmentation
# License(s): copyright-authors
# ...
#  58% 14.0M/24.2M [00:00<00:00, 63.2MB/s]
# 100% 24.2M/24.2M [00:00<00:00, 75.1MB/s]

# %%
import zipfile
zip_file = zipfile.ZipFile('bank-customer-segmentation.zip')
zip_file.extractall()
zip_file.close()

# %%
df = pd.read_csv(r'bank_transactions.csv')
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 0                  T1   C5841053     10/1/94          F     JAMSHEDPUR
# 1                  T2   C2142763      4/4/57          M        JHAJJAR
# 2                  T3   C4417068    26/11/96          F         MUMBAI
# 3                  T4   C5342380     14/9/73          F         MUMBAI
# 4                  T5   C9031234     24/3/88          F    NAVI MUMBAI
# ...               ...        ...         ...        ...            ...
# 1048562      T1048563   C8020229      8/4/90          M      NEW DELHI
# 1048563      T1048564   C6459278     20/2/92          M         NASHIK
# 1048564      T1048565   C6412354     18/5/89          M      HYDERABAD
# 1048565      T1048566   C6420483     30/8/78          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524      5/3/84          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df.columns
# Out:
# Index(['TransactionID', 'CustomerID', 'CustomerDOB', 'CustGender',
#        'CustLocation', 'CustAccountBalance', 'TransactionDate',
#        'TransactionTime', 'TransactionAmount (INR)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048567 entries, 0 to 1048566
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   TransactionID            1048567 non-null  object
#  1   CustomerID               1048567 non-null  object
#  2   CustomerDOB              1045170 non-null  object
#  3   CustGender               1047467 non-null  object
#  4   CustLocation             1048416 non-null  object
#  5   CustAccountBalance       1046198 non-null  float64
#  6   TransactionDate          1048567 non-null  object
#  7   TransactionTime          1048567 non-null  int64
#  8   TransactionAmount (INR)  1048567 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 72.0+ MB

# %%
df.drop(columns=['TransactionID', 'CustomerID', 'CustomerDOB'], axis=1, inplace=True)

# %%
df.describe()
# Out:
#        CustAccountBalance  TransactionTime  TransactionAmount (INR)
# count        1.046198e+06     1.048567e+06             1.048567e+06
# mean         1.154035e+05     1.570875e+05             1.574335e+03
# std          8.464854e+05     5.126185e+04             6.574743e+03
# min          0.000000e+00     0.000000e+00             0.000000e+00
# 25%          4.721760e+03     1.240300e+05             1.610000e+02
# 50%          1.679218e+04     1.642260e+05             4.590300e+02
# 75%          5.765736e+04     2.000100e+05             1.200000e+03
# max          1.150355e+08     2.359590e+05             1.560035e+06

# %%
df.isnull().sum()
# Out:
# CustGender                 1100
# CustLocation                151
# CustAccountBalance         2369
# TransactionDate               0
# TransactionTime               0
# TransactionAmount (INR)       0
# dtype: int64

# %%
df.dropna(subset=['CustGender', 'CustLocation'], inplace=True)

# %%
df.isnull().sum()
# Out:
# CustGender                    0
# CustLocation                  0
# CustAccountBalance         2369
# TransactionDate               0
# TransactionTime               0
# TransactionAmount (INR)       0
# dtype: int64

# %%
df.CustAccountBalance.median(), df.CustAccountBalance.mean()
# Out:
# (16817.13, 115274.97815950484)

# %%
df.CustAccountBalance.fillna(df.CustAccountBalance.median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# CustGender                 0
# CustLocation               0
# CustAccountBalance         0
# TransactionDate            0
# TransactionTime            0
# TransactionAmount (INR)    0
# dtype: int64

# %%
df.to_csv('cleaned_df.csv', index=False)
